# %%
import importlib
import dataset
from dataset import Dataset
importlib.reload(dataset) # prevent cache when making changes
importlib.reload(dataset) # prevent cache when making changes
ds = Dataset("tracks")
print(len(ds))
# Out:
# Loading data from "tracks\**\*.wav"
# 3

# %%
label, clips,spectros = ds[0]
# Out:
# d:\Repos\Other\slap\dataset.py:53: FutureWarning: Pass size=2355200 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   audio = librosa.util.fix_length(audio, full_length)

# %%
import numpy as np
print(label, ds.label_encoder.inverse_transform([np.argmax(label)])[0], len(clips),len(spectros))
# Out:
# tensor([0, 1, 0]) family affair 92 92

# %%
ds.show_spectros(spectros[:3])

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labels = ["a","b","c"]
le = LabelEncoder()
z = le.fit_transform(labels)
print(z)
enc = le.transform(labels[::-1])
print(enc)
print(le.inverse_transform([2,0,1]))
print(len(le.classes_))
# Out:
# [0 1 2]
# [2 1 0]
# ['c' 'a' 'b']
# 3

# %%
import torch.nn.functional as F
import torch
example = "c"
enc = torch.tensor(le.transform([example]), dtype=torch.int64)
print(enc)
print(F.one_hot(enc[0], num_classes=len(le.classes_)))
# Out:
# tensor([2])
# tensor([0, 0, 1])
